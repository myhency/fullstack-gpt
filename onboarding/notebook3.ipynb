# %%
from langchain.chat_models import ChatOllama
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler
from langchain.prompts.few_shot import FewShotPromptTemplate, FewShotChatMessagePromptTemplate
from langchain.prompts.example_selector import LengthBasedExampleSelector

chat = ChatOllama(temperature=0.1, streaming=True, callbacks=[StreamingStdOutCallbackHandler()])

# t = PromptTemplate(
#     template="What is the capital of {country}",
#     input_variables=["country"]
# )

# t.format(country="France")

examples = [
    {
        "question": "France",
        "answer": """
        Here is what I know:
        Capital: Paris
        Language: French
        Food: Whine and Cheese
        Currency: Euro
        """
    },
    {
        "question": "Italy",
        "answer": """
        I know this:
        Capital: Rome
        Language: Italian
        Food: Pizza and Pasta
        Currency: Euro
        """
    },
    {
        "question": "Greece",
        "answer": """
        I know this:
        Capital: Athens
        Language: Greek
        Food: Souvlaki and Feta Cheese
        Currency: Euro
        """
    }
]

# chat.predict("What do you know about France?")

example_template = """
    Human: {question}
    AI: {answer}
"""

example_prompt = ChatPromptTemplate.from_messages([
    ("human", "What do you know about {question}"),
    ("ai", "{answer}")
])

example_selector = LengthBasedExampleSelector(
    examples=examples,
    example_prompt=example_prompt,
    max_length=10
)

prompt = FewShotPromptTemplate(
    example_prompt=example_prompt,
    example_selector=example_selector,
    suffix="Human: What do you know about {country}?",
    input_variables=["country"]
)

prompt.format(country="Brazil")

# example_prompt = FewShotChatMessagePromptTemplate(
#     example_prompt=example_prompt,
#     examples=examples
# )

# final_prompt = ChatPromptTemplate.from_messages([
#     ("system", "You are a geography expert, you give the short answer"),
#     example_prompt,
#     ("human", "What do you know about {question}")
# ])

# # prompt.format(country="Germany")

# chain = final_prompt | chat

# chain.invoke({
#     "question": "Thailand"
# })
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 61
#      51 example_template = """
#      52     Human: {question}
#      53     AI: {answer}
#      54 """
#      56 example_prompt = ChatPromptTemplate.from_messages([
#      57     ("human", "What do you know about {question}"),
#      58     ("ai", "{answer}")
#      59 ])
# ---> 61 example_selector = LengthBasedExampleSelector(
#      62     examples=examples,
#      63     example_prompt=example_prompt,
#      64     max_length=10
#      65 )
#      67 prompt = FewShotPromptTemplate(
#      68     example_prompt=example_prompt,
#      69     example_selector=example_selector,
#      70     suffix="Human: What do you know about {country}?",
#      71     input_variables=["country"]
#      72 )
#      74 prompt.format(country="Brazil")
#
# File ~/myprojects/fullstack-gpt/env/lib/python3.11/site-packages/pydantic/main.py:339, in pydantic.main.BaseModel.__init__()
#
# File ~/myprojects/fullstack-gpt/env/lib/python3.11/site-packages/pydantic/main.py:1076, in pydantic.main.validate_model()
#
# File ~/myprojects/fullstack-gpt/env/lib/python3.11/site-packages/pydantic/fields.py:884, in pydantic.fields.ModelField.validate()
#
# File ~/myprojects/fullstack-gpt/env/lib/python3.11/site-packages/pydantic/fields.py:1101, in pydantic.fields.ModelField._validate_singleton()
#
# File ~/myprojects/fullstack-gpt/env/lib/python3.11/site-packages/pydantic/fields.py:1157, in pydantic.fields.ModelField._apply_validators()
#
# File ~/myprojects/fullstack-gpt/env/lib/python3.11/site-packages/pydantic/class_validators.py:337, in pydantic.class_validators._generic_validator_basic.lambda13()
#
# File ~/myprojects/fullstack-gpt/env/lib/python3.11/site-packages/pydantic/main.py:719, in pydantic.main.BaseModel.validate()
#
# File ~/myprojects/fullstack-gpt/env/lib/python3.11/site-packages/langchain/load/serializable.py:97, in Serializable.__init__(self, **kwargs)
#      96 def __init__(self, **kwargs: Any) -> None:
# ---> 97     super().__init__(**kwargs)
#      98     self._lc_kwargs = kwargs
#
# File ~/myprojects/fullstack-gpt/env/lib/python3.11/site-packages/pydantic/main.py:339, in pydantic.main.BaseModel.__init__()
#
# File ~/myprojects/fullstack-gpt/env/lib/python3.11/site-packages/pydantic/main.py:1102, in pydantic.main.validate_model()
#
# File ~/myprojects/fullstack-gpt/env/lib/python3.11/site-packages/langchain/prompts/prompt.py:140, in PromptTemplate.template_is_valid(cls, values)
#     133     check_valid_template(
#     134         values["template"], values["template_format"], all_inputs
#     135     )
#     136 elif values.get("template_format"):
#     137     values["input_variables"] = [
#     138         var
#     139         for var in get_template_variables(
# --> 140             values["template"], values["template_format"]
#     141         )
#     142         if var not in values["partial_variables"]
#     143     ]
#     144 return values
#
# KeyError: 'template'
